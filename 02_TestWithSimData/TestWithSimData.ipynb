# %%
#imports
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image

from functions.ImageEncoder import image_encoder
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 from PIL import Image
#       7 from functions.ImageEncoder import image_encoder
# ----> 9 image_encoder()
#
# TypeError: image_encoder() missing 2 required positional arguments: 'data' and 'out_path'
